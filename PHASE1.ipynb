# %% [markdown]
# Data Testing With Model

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
houses = pd.read_csv('housing.csv')
houses.shape
#20,000 Columns is a good standard of the average that is there (THIS DATA IS BASED ON YEAR 1990)
# Out:
# (20640, 10)

# %%
houses.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.6 MB

# %%
plt.hist(houses['median_house_value'],bins = 20, edgecolor = 'black')
plt.show()

# %%
#this shows us the average home price in california in 199- was around 140 - 160 thousand dollars.

# %%
houses.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#there is some missing data when it comes to total bedrooms it also appears that the median income is not a standard value but a decimal value. Will look more into that.

# %%
houses['median_income'].head() 
#this is measured in 10,000 chunks i believe. meaning to get the true value to follor the rest of this data set we will need to multiple the number by 10,000 
#I do not care about the longitude and lattitude so i will be getting rid of them
# Out:
# 0    8.3252
# 1    8.3014
# 2    7.2574
# 3    5.6431
# 4    3.8462
# Name: median_income, dtype: float64

# %%
houses['Income_In_Thousands'] = houses['median_income'] * 10000 
houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
#houses = houses.drop('longitude',axis = 1)
#houses = houses.drop('latitude',axis = 1)
houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
sns.boxplot(data=houses, x = 'ocean_proximity', y='median_house_value')
plt.show()
#shows us that the cheapest average houses are inland while the most expensive on average are on Islands. This makes sense and is valid for the data as the more expensive it is the closer to the ocean.

# %%
houses1 = pd.read_csv('CA-1.csv')
houses2 = pd.read_csv('CA-2.csv')
houses3 = pd.read_csv('CA-3.csv')

# %%
houses1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 27 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   SALE TYPE                                                                                    351 non-null    str
#  1   SOLD DATE                                                                                    0 non-null      float64
#  2   PROPERTY TYPE                                                                                350 non-null    str
#  3   ADDRESS                                                                                      350 non-null    str
#  4   CITY                                                                                         349 non-null    str
# ...

# %%
houses2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 27 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   SALE TYPE                                                                                    351 non-null    str
#  1   SOLD DATE                                                                                    0 non-null      float64
#  2   PROPERTY TYPE                                                                                350 non-null    str
#  3   ADDRESS                                                                                      350 non-null    str
#  4   CITY                                                                                         350 non-null    str
# ...

# %%
houses3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 27 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   SALE TYPE                                                                                    180 non-null    str
#  1   SOLD DATE                                                                                    0 non-null      float64
#  2   PROPERTY TYPE                                                                                179 non-null    str
#  3   ADDRESS                                                                                      179 non-null    str
#  4   CITY                                                                                         178 non-null    str
# ...

# %%
#GIVEN THAT THEY ALL HAVE THE SAME DATA I WILL JOIN THEM TOGETHER WHEN WE GET TO THAT IN CLASS.
